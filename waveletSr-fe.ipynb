# %%
import scipy.io as sio
from pyleoclim import Spectral

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
cd /Users/kurtwogau/Documents/
# Out:
# /Users/kurtwogau/Documents

# %%
cd TimesSeries/
# Out:
# /Users/kurtwogau/Documents/TimesSeries

# %%
ls
# Out:
# 2500yrData2.csv

# %%
data = pd.read_csv("2500yrData2.csv")

# %%
data
# Out:
#          Yr BP     Sr/Fe     Ti  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      1999.97  0.410811  617.0         NaN         NaN         NaN
# 1      1999.78  0.374046  662.0         NaN         NaN         NaN
# 2      1999.59  0.336861  618.0         NaN         NaN         NaN
# 3      1999.41  0.409222  608.0         NaN         NaN         NaN
# 4      1999.22  0.384615  635.0         NaN         NaN         NaN
# 5      1999.03  0.450633  549.0         NaN         NaN         NaN
# 6      1998.85  0.361832  563.0         NaN         NaN         NaN
# 7      1998.66  0.426716  714.0         NaN         NaN         NaN
# 8      1998.47  0.359741  645.0         NaN         NaN         NaN
# 9      1998.29  0.370518  602.0         NaN         NaN         NaN
# 10     1998.10  0.325706  649.0         NaN         NaN         NaN
# 11     1997.91  0.364790  659.0         NaN         NaN         NaN
# 12     1997.73  0.378872  540.0         NaN         NaN         NaN
# 13     1997.54  0.379100  598.0         NaN         NaN         NaN
# 14     1997.35  0.386091  532.0         NaN         NaN         NaN
# 15     1997.17  0.379046  621.0         NaN         NaN         NaN
# 16     1996.98  0.344167  575.0         NaN         NaN         NaN
# 17     1996.79  0.385017  615.0         NaN         NaN         NaN
# 18     1996.61  0.347170  708.0         NaN         NaN         NaN
# 19     1996.42  0.409629  503.0         NaN         NaN         NaN
# 20     1996.23  0.361821  619.0         NaN         NaN         NaN
# 21     1996.05  0.341648  699.0         NaN         NaN         NaN
# 22     1995.86  0.363380  757.0         NaN         NaN         NaN
# 23     1995.67  0.329734  716.0         NaN         NaN         NaN
# 24     1995.49  0.419482  551.0         NaN         NaN         NaN
# 25     1995.30  0.354956  526.0         NaN         NaN         NaN
# 26     1995.11  0.333801  706.0         NaN         NaN         NaN
# 27     1994.93  0.412117  777.0         NaN         NaN         NaN
# 28     1994.74  0.328265  584.0         NaN         NaN         NaN
# 29     1994.55  0.411486  816.0         NaN         NaN         NaN
# ...        ...       ...    ...         ...         ...         ...
# 23054      NaN       NaN    NaN         NaN         NaN         NaN
# 23055      NaN       NaN    NaN         NaN         NaN         NaN
# 23056      NaN       NaN    NaN         NaN         NaN         NaN
# 23057      NaN       NaN    NaN         NaN         NaN         NaN
# 23058      NaN       NaN    NaN         NaN         NaN         NaN
# 23059      NaN       NaN    NaN         NaN         NaN         NaN
# 23060      NaN       NaN    NaN         NaN         NaN         NaN
# 23061      NaN       NaN    NaN         NaN         NaN         NaN
# 23062      NaN       NaN    NaN         NaN         NaN         NaN
# 23063      NaN       NaN    NaN         NaN         NaN         NaN
# 23064      NaN       NaN    NaN         NaN         NaN         NaN
# 23065      NaN       NaN    NaN         NaN         NaN         NaN
# 23066      NaN       NaN    NaN         NaN         NaN         NaN
# 23067      NaN       NaN    NaN         NaN         NaN         NaN
# 23068      NaN       NaN    NaN         NaN         NaN         NaN
# 23069      NaN       NaN    NaN         NaN         NaN         NaN
# 23070      NaN       NaN    NaN         NaN         NaN         NaN
# 23071      NaN       NaN    NaN         NaN         NaN         NaN
# 23072      NaN       NaN    NaN         NaN         NaN         NaN
# 23073      NaN       NaN    NaN         NaN         NaN         NaN
# 23074      NaN       NaN    NaN         NaN         NaN         NaN
# 23075      NaN       NaN    NaN         NaN         NaN         NaN
# 23076      NaN       NaN    NaN         NaN         NaN         NaN
# 23077      NaN       NaN    NaN         NaN         NaN         NaN
# 23078      NaN       NaN    NaN         NaN         NaN         NaN
# 23079      NaN       NaN    NaN         NaN         NaN         NaN
# 23080      NaN       NaN    NaN         NaN         NaN         NaN
# 23081      NaN       NaN    NaN         NaN         NaN         NaN
# 23082      NaN       NaN    NaN         NaN         NaN         NaN
# 23083      NaN       NaN    NaN         NaN         NaN         NaN
#
#        Unnamed: 6
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# ...           ...
# 23054         NaN
# 23055         NaN
# 23056         NaN
# 23057         NaN
# 23058         NaN
# 23059         NaN
# 23060         NaN
# 23061         NaN
# 23062         NaN
# 23063         NaN
# 23064         NaN
# 23065         NaN
# 23066         NaN
# 23067         NaN
# 23068         NaN
# 23069         NaN
# 23070         NaN
# 23071         NaN
# 23072         NaN
# 23073         NaN
# 23074         NaN
# 23075         NaN
# 23076         NaN
# 23077         NaN
# 23078         NaN
# 23079         NaN
# 23080         NaN
# 23081         NaN
# 23082         NaN
# 23083         NaN
#
# [23084 rows x 7 columns]

# %%
tau = np.linspace(np.min(t), np.max(t), 201)
scale = np.logspace(-2, 7, num=51, base=2)
freqs = 1/scale[::-1]

res_xwc = Spectral.xwc(
    nino, t, air, t, tau=tau, nMC=0, freqs=freqs,
#     smooth_factor=0.025 # the larger, the smoother
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6ac3add25c7b> in <module>()
# ----> 1 tau = np.linspace(np.min(t), np.max(t), 201)
#       2 scale = np.logspace(-2, 7, num=51, base=2)
#       3 freqs = 1/scale[::-1]
#       4
#       5 res_xwc = Spectral.xwc(
#
# NameError: name 't' is not defined
