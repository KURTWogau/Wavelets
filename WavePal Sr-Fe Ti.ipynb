# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import wavepal as wv
import pandas as pd

# %%
ls
# Out:
# 2500yrData2.csv         SST.csv                 WavePal Sr-Fe Ti.ipynb
# Cariaco.csv             SolarActivity.csv
# El Junco .csv           Sr-FEWAVELET.ipynb

# %%
data = pd.read_csv("2500yrData2.csv")

# %%
x1 = data['Sr/Fe'].values
y1 = data['Ti'].values
t  = data['Yr BP'].values

# %%
t
# Out:
# array([1.99997e+03, 1.99978e+03, 1.99959e+03, ..., 3.20000e-01,
#        1.80000e-01, 4.00000e-02])

# %%
x = wv.Wavepal(t,x1,"Age","Sr/Fe",t_units="yr",mydata_units="CPS")

# %%
help(x.__init__)
# Out:
# Help on method __init__ in module wavepal.Wavepal:
#
# __init__(self, t, mydata, t_axis_label='', mydata_axis_label='', t_units=None, mydata_units=None) method of wavepal.Wavepal.Wavepal instance
#     Constructor of Wavepal class. It Initializes all the variables of Wavepal class with an access outside Wavepal (the user can access them). The list of available variables is given in this function.
#     Required Inputs:
#     - t [1-dim numpy array of floats]: the times of the time series, distinct and in ascending order.
#     - mydata [1-dim numpy array of floats - size=time.size]: the data at the times given by 't'.
#     Optional Inputs:
#     - t_axis_label="": label for the time axis in figures
#     - mydata_axis_label="": label for the data axis in figures
#     - t_units=None: units of 't' (string type)
#     - mydata_units=None: units of 'mydata' (string type).
#     Outputs:
#     /
#     -----------------------------
#     This is part of WAVEPAL
#     (C) 2016 G. Lenoir

# %%
x.check_data()
# Out:
# WARNING: The times/ages of the time series must be distinct
# The program will automatically select the first occurrence of the time/age (and skip the others) where they are the same (times/ages are previously set in ascending order)
# same time/age at  243.08
# same time/age at  960.44
# same time/age at  1596.15

# %%
plot_timestep=x.plot_timestep()
#plot_timestep.show()

# %%
plot_trend=x.plot_trend(pol_degree=-1)    # no trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=0)    # constant trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=5)    
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=7)   
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=9)    
plot_trend.show()

# %%
x.choose_trend_degree(7)

# %%
x.trend_vectors()

# %%
x.carma_params(make_carma_fig=True,nbins=20,dpi=400,path_to_figure_folder="/Users/kurtwogau/Documents/")
# Out:
# ****************************
# *        CARMA PACK        *
# ****************************
#
# FIRST ROUND (to estimate the number of independent samples): with  10000  samples
# **********************************************************************************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Decorrelation length (in number of samples) - Estimation:  15
#
# SECOND ROUND: generates  15000  samples
# ***************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Decorrelation length (in number of samples):  12
# **************************************
# *        BUILD CARMA MATRIX K        *
# **************************************
# Computing the median parameters of the CAR-1 process from  1250  MCMC samples.
# Median parameters:
# --------------------
# alpha:  0.16917931823100874
# std white noise:  0.37002140312228904

# %%
percentile=np.zeros(2)
percentile[0]=95.
percentile[1]=90.

# %%
x.freq_analysis(freqstep=0.0001,D=600.,percentile=percentile,n_moments=12,computes_amplitude=True)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Re-estimated D factor (WOSA):  615.363076923077
# Preliminary steps for the WOSA periodogram:
# 100%|██████████| 10/10 [00:02<00:00,  3.66it/s]
#   0%|          | 0/11755 [00:00<?, ?it/s]
# Re-estimated frequency range: from  0.0017000199002213275  to  1.177102370317047
# Main loop, over the frequencies:
# 100%|██████████| 11755/11755 [42:30<00:00,  4.61it/s]

# %%
plot_periodogram=x.plot_periodogram(fontsize_legend=10)
plot_periodogram.show()

# %%
theta=np.linspace(t[0],t[-1],2000)

# %%
x.timefreq_analysis(theta=theta,w0=5.5,permin=10.,percentile=percentile)
# Out:
#   0%|          | 1/2000 [00:00<04:08,  8.04it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [04:22<00:00,  7.63it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
# Re-estimated period range: from  10.0  to  320.0
# Main loop, over the time-frequency plane:
# 100%|██████████| 101/101 [48:18<00:00, 28.70s/it]

# %%
time_string=[0., 500., 1000., 1500., 2000., 2500.,]
period_string=[11., 21., 41.,65.,130., 200., 400.,600.,]
dashed_periods=[11., 65., 130.]

# %%
plot_scalogram=x.plot_scalogram(color_cl_anal=['m','g'],fontsize_title=30,fontsize_ticks=20,fontsize_axes=20,time_string=time_string,period_string=period_string,dashed_periods=dashed_periods,linewidth_cl=4,global_scal_xlabel_ticks="bottom",decimals=2,linewidth_gscal=2.0)
fig = plt.gcf() 
fig.set_size_inches(24,12)
plot_scalogram.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import wavepal as wv
import pandas as pd

# %%
ls
# Out:
# 2500yrData2.csv         SST.csv                 WavePal Sr-Fe Ti.ipynb
# Cariaco.csv             SolarActivity.csv
# El Junco .csv           Sr-FEWAVELET.ipynb

# %%
data = pd.read_csv("SST.csv")

# %%
x1 = data['SST'].values
t  = data['Yr CE'].values

# %%
x1
# Out:
# array([27.9806, 28.0045, 28.063 , ..., 29.1327, 29.1444, 28.2011])

# %%
x = wv.Wavepal(t,x1,"Age","Ti",t_units="yr",mydata_units="CPS")

# %%
help(x.__init__)
# Out:
# Help on method __init__ in module wavepal.Wavepal:
#
# __init__(self, t, mydata, t_axis_label='', mydata_axis_label='', t_units=None, mydata_units=None) method of wavepal.Wavepal.Wavepal instance
#     Constructor of Wavepal class. It Initializes all the variables of Wavepal class with an access outside Wavepal (the user can access them). The list of available variables is given in this function.
#     Required Inputs:
#     - t [1-dim numpy array of floats]: the times of the time series, distinct and in ascending order.
#     - mydata [1-dim numpy array of floats - size=time.size]: the data at the times given by 't'.
#     Optional Inputs:
#     - t_axis_label="": label for the time axis in figures
#     - mydata_axis_label="": label for the data axis in figures
#     - t_units=None: units of 't' (string type)
#     - mydata_units=None: units of 'mydata' (string type).
#     Outputs:
#     /
#     -----------------------------
#     This is part of WAVEPAL
#     (C) 2016 G. Lenoir

# %%
x.check_data()

# %%
plot_timestep=x.plot_timestep()
#plot_timestep.show()

# %%
plot_trend=x.plot_trend(pol_degree=-1)    # no trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=0)    # constant trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=5)    
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=7)   
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=9)    
plot_trend.show()

# %%
x.choose_trend_degree(7)

# %%
x.trend_vectors()

# %%
x.carma_params(make_carma_fig=True,nbins=20,dpi=400,path_to_figure_folder="/Users/kurtwogau/Documents/")
# Out:
# ****************************
# *        CARMA PACK        *
# ****************************
#
# FIRST ROUND (to estimate the number of independent samples): with  10000  samples
# **********************************************************************************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Decorrelation length (in number of samples) - Estimation:  15
#
# SECOND ROUND: generates  15000  samples
# ***************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Decorrelation length (in number of samples):  16
# **************************************
# *        BUILD CARMA MATRIX K        *
# **************************************
# Computing the median parameters of the CAR-1 process from  938  MCMC samples.
# Median parameters:
# --------------------
# alpha:  0.13045248529428022
# std white noise:  0.13544294114866068

# %%
percentile=np.zeros(2)
percentile[0]=95.
percentile[1]=90.

# %%
x.freq_analysis(freqstep=0.00001,D=600.,percentile=percentile,n_moments=12,computes_amplitude=True)
# Out:
#  20%|██        | 2/10 [00:00<00:00, 18.43it/s]
# Re-estimated D factor (WOSA):  617.8461538461538
# Preliminary steps for the WOSA periodogram:
# 100%|██████████| 10/10 [00:00<00:00, 20.36it/s]
#   0%|          | 4/49837 [00:00<22:28, 36.95it/s]
# Re-estimated frequency range: from  0.0016280124746260204  to  0.4999899999601195
# Main loop, over the frequencies:
# 100%|██████████| 49837/49837 [18:55<00:00, 43.90it/s]

# %%
plot_periodogram=x.plot_periodogram(fontsize_legend=10)
plot_periodogram.show()

# %%
theta=np.linspace(t[0],t[-1],2000)

# %%
x.timefreq_analysis(theta=theta,w0=5.5,permin=10.,percentile=percentile)
# Out:
#   0%|          | 4/2000 [00:00<01:03, 31.30it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [01:32<00:00, 21.62it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
# Re-estimated period range: from  10.0  to  320.0
# Main loop, over the time-frequency plane:
# 100%|██████████| 101/101 [11:51<00:00,  7.05s/it]

# %%
time_string=[0., 500., 1000., 1500., 2000., 2500.,]
period_string=[11., 21.,30., 41., 60., 100., 200., 400.,]
dashed_periods=[11.,21., 30., 60.]

# %%
plot_scalogram=x.plot_scalogram(color_cl_anal=['m','g'],fontsize_title=30,fontsize_ticks=20,fontsize_axes=20,time_string=time_string,period_string=period_string,dashed_periods=dashed_periods,linewidth_cl=4,global_scal_xlabel_ticks="bottom",decimals=2,linewidth_gscal=2.0)
fig = plt.gcf() 
fig.set_size_inches(24,12)
plot_scalogram.show()

# %%
y=copy.copy(x)  # optional: in order to keep in memory all what we did up to here (very convenient if you work with ipython)
y.timefreq_analysis(theta=theta,w0=15.0,permin=10.,percentile=percentile)
# Out:
#   0%|          | 4/2000 [00:00<00:57, 34.82it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [01:15<00:00, 26.39it/s]
#   0%|          | 0/72 [00:00<?, ?it/s]
# Re-estimated period range: from  10.0  to  117.12685567565005
# Main loop, over the time-frequency plane:
# 100%|██████████| 72/72 [08:52<00:00,  7.40s/it]

# %%
plot_scalogram=y.plot_scalogram(color_cl_anal=['m','g'],fontsize_title=40,fontsize_ticks=20,fontsize_axes=30,time_string=time_string,period_string=period_string,dashed_periods=dashed_periods,linewidth_cl=4,global_scal_xlabel_ticks="bottom",decimals=2,linewidth_gscal=2.0)
fig = plt.gcf()
fig.set_size_inches(24,12)
plot_scalogram.show()

# %%
ls
# Out:
# 2500yrData2.csv         SST.csv                 WavePal Sr-Fe Ti.ipynb
# El Junco.csv            Sr-FEWAVELET.ipynb

# %%
data = pd.read_csv("2500yrData2.csv")

# %%
x1 = data['Sr/Fe'].values
y1 = data['Ti'].values
t  = data['Yr BP'].values

# %%
x = wv.Wavepal(t,y1,"Age","Ti",t_units="yr",mydata_units="CPS")

# %%
help(x.__init__)
# Out:
# Help on method __init__ in module wavepal.Wavepal:
#
# __init__(self, t, mydata, t_axis_label='', mydata_axis_label='', t_units=None, mydata_units=None) method of wavepal.Wavepal.Wavepal instance
#     Constructor of Wavepal class. It Initializes all the variables of Wavepal class with an access outside Wavepal (the user can access them). The list of available variables is given in this function.
#     Required Inputs:
#     - t [1-dim numpy array of floats]: the times of the time series, distinct and in ascending order.
#     - mydata [1-dim numpy array of floats - size=time.size]: the data at the times given by 't'.
#     Optional Inputs:
#     - t_axis_label="": label for the time axis in figures
#     - mydata_axis_label="": label for the data axis in figures
#     - t_units=None: units of 't' (string type)
#     - mydata_units=None: units of 'mydata' (string type).
#     Outputs:
#     /
#     -----------------------------
#     This is part of WAVEPAL
#     (C) 2016 G. Lenoir

# %%
x.check_data()
# Out:
# WARNING: The times/ages of the time series must be distinct
# The program will automatically select the first occurrence of the time/age (and skip the others) where they are the same (times/ages are previously set in ascending order)
# same time/age at  243.08
# same time/age at  960.44
# same time/age at  1596.15

# %%
plot_timestep=x.plot_timestep()
plot_timestep.show()

# %%
plot_trend=x.plot_trend(pol_degree=7)   
plot_trend.show()

# %%
x.choose_trend_degree(7)

# %%
x.trend_vectors()

# %%
x.carma_params(make_carma_fig=True,nbins=20,dpi=400,path_to_figure_folder="/Users/kurtwogau/Documents/")
# Out:
# ****************************
# *        CARMA PACK        *
# ****************************
#
# FIRST ROUND (to estimate the number of independent samples): with  10000  samples
# **********************************************************************************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Decorrelation length (in number of samples) - Estimation:  1517
#
# SECOND ROUND: generates  1000000  samples
# ***************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Decorrelation length (in number of samples):  13
# **************************************
# *        BUILD CARMA MATRIX K        *
# **************************************
# Computing the median parameters of the CAR-1 process from  76924  MCMC samples.
# Median parameters:
# --------------------
# alpha:  0.13333347217050584
# std white noise:  2409.307575245794

# %%
percentile=np.zeros(2)
percentile[0]=95.
percentile[1]=99.9

# %%
theta=np.linspace(t[0],t[-1],2000)

# %%
x.timefreq_analysis(theta=theta,w0=5.5,permin=10.,percentile=percentile)
# Out:
#   0%|          | 1/2000 [00:00<03:53,  8.54it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [04:20<00:00,  7.69it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
# Re-estimated period range: from  10.0  to  320.0
# Main loop, over the time-frequency plane:
# 100%|██████████| 101/101 [43:38<00:00, 25.92s/it]

# %%
time_string=[0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500., 5000., 5500., 6000.]
period_string=[10., 21., 41.,60., 100., 200., 400., 800., 1500.]
dashed_periods=[21., 41., 100.]

# %%
plot_scalogram=x.plot_scalogram(color_cl_anal=['m','g'],fontsize_title=30,fontsize_ticks=20,fontsize_axes=20,time_string=time_string,period_string=period_string,dashed_periods=dashed_periods,linewidth_cl=4,global_scal_xlabel_ticks="bottom",decimals=2,linewidth_gscal=2.0)
fig = plt.gcf() 
fig.set_size_inches(24,12)
plot_scalogram.show()

# %%
ls
# Out:
# 2500yrData2.csv         SST.csv                 WavePal Sr-Fe Ti.ipynb
# Cariaco.csv             SolarActivity.csv
# El Junco.csv            Sr-FEWAVELET.ipynb

# %%
data = pd.read_csv(".csv")

# %%
data;

# %%
x1 = data['dTSI'].values
t = data['Yr CE'].values

# %%
x = wv.Wavepal(t,x1,"Age","dTSI",t_units="yr",mydata_units="CPS")

# %%
help(x.__init__)
# Out:
# Help on method __init__ in module wavepal.Wavepal:
#
# __init__(self, t, mydata, t_axis_label='', mydata_axis_label='', t_units=None, mydata_units=None) method of wavepal.Wavepal.Wavepal instance
#     Constructor of Wavepal class. It Initializes all the variables of Wavepal class with an access outside Wavepal (the user can access them). The list of available variables is given in this function.
#     Required Inputs:
#     - t [1-dim numpy array of floats]: the times of the time series, distinct and in ascending order.
#     - mydata [1-dim numpy array of floats - size=time.size]: the data at the times given by 't'.
#     Optional Inputs:
#     - t_axis_label="": label for the time axis in figures
#     - mydata_axis_label="": label for the data axis in figures
#     - t_units=None: units of 't' (string type)
#     - mydata_units=None: units of 'mydata' (string type).
#     Outputs:
#     /
#     -----------------------------
#     This is part of WAVEPAL
#     (C) 2016 G. Lenoir

# %%
x.check_data()

# %%
plot_timestep=x.plot_timestep()
plot_timestep.show()

# %%
plot_trend=x.plot_trend(pol_degree=-1)    # no trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=0)    # constant trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=5)    
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=7)   
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=9)    
plot_trend.show()

# %%
x.choose_trend_degree(7)

# %%
x.trend_vectors()

# %%
x.carma_params(make_carma_fig=True,nbins=20,dpi=400,path_to_figure_folder="/Users/kurtwogau/Documents/")
# Out:
# ****************************
# *        CARMA PACK        *
# ****************************
#
# FIRST ROUND (to estimate the number of independent samples): with  10000  samples
# **********************************************************************************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Decorrelation length (in number of samples) - Estimation:  16
#
# SECOND ROUND: generates  16000  samples
# ***************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Decorrelation length (in number of samples):  19
# **************************************
# *        BUILD CARMA MATRIX K        *
# **************************************
# Computing the median parameters of the CAR-1 process from  843  MCMC samples.
# Median parameters:
# --------------------
# alpha:  0.032848781883480505
# std white noise:  0.018313604198334534

# %%
x.freq_analysis(freqstep=0.0001,D=600.,percentile=percentile,n_moments=12,computes_amplitude=True)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 301.43it/s]
#   2%|▏         | 15/983 [00:00<00:06, 138.66it/s]
# Re-estimated D factor (WOSA):  615.3846153846154
# Preliminary steps for the WOSA periodogram:
# Re-estimated frequency range: from  0.0017000000000000001  to  0.0999
# Main loop, over the frequencies:
# 100%|██████████| 983/983 [00:06<00:00, 150.95it/s]

# %%
plot_periodogram=x.plot_periodogram(fontsize_legend=10)
plot_periodogram.show()

# %%
theta=np.linspace(t[0],t[-1],2000)

# %%
x.timefreq_analysis(theta=theta,w0=5.5,permin=10.,percentile=percentile)
# Out:
#   0%|          | 8/2000 [00:00<00:28, 70.46it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [00:39<00:00, 50.87it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Re-estimated period range: from  10.352659591063013  to  320.00032
# Main loop, over the time-frequency plane:
# 100%|██████████| 100/100 [06:51<00:00,  4.11s/it]

# %%
time_string=[0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500., 5000., 5500., 6000.]
period_string=[10., 21., 41., 60., 100., 200., 400., 800., 1500.]
dashed_periods=[21., 41., 100.]

# %%
plot_scalogram=x.plot_scalogram(color_cl_anal=['m','g'],fontsize_title=30,fontsize_ticks=20,fontsize_axes=20,time_string=time_string,period_string=period_string,dashed_periods=dashed_periods,linewidth_cl=4,global_scal_xlabel_ticks="bottom",decimals=2,linewidth_gscal=2.0)
fig = plt.gcf() 
fig.set_size_inches(24,12)
plot_scalogram.show()

# %%
y=copy.copy(x)  # optional: in order to keep in memory all what we did up to here (very convenient if you work with ipython)
y.timefreq_analysis(theta=theta,w0=15.0,permin=10.,percentile=percentile)
# Out:
#   0%|          | 9/2000 [00:00<00:22, 87.16it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [00:28<00:00, 69.78it/s]
#   0%|          | 0/71 [00:00<?, ?it/s]
# Re-estimated period range: from  10.352659591063013  to  117.12697280250573
# Main loop, over the time-frequency plane:
# 100%|██████████| 71/71 [05:15<00:00,  4.44s/it]

# %%
y=copy.copy(x)  
y.timefreq_analysis(theta=theta,w0=15.0,permin=10.,percentile=percentile)
# Out:
#   0%|          | 9/2000 [00:00<00:23, 86.00it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [00:27<00:00, 73.36it/s]
#   0%|          | 0/71 [00:00<?, ?it/s]
# Re-estimated period range: from  10.352659591063013  to  117.12697280250573
# Main loop, over the time-frequency plane:
# 100%|██████████| 71/71 [05:27<00:00,  4.61s/it]

# %%
plot_scalogram=y.plot_scalogram(color_cl_anal=['m','g'],fontsize_title=40,fontsize_ticks=20,fontsize_axes=30,time_string=time_string,period_string=period_string,dashed_periods=dashed_periods,linewidth_cl=4,global_scal_xlabel_ticks="bottom",decimals=2,linewidth_gscal=2.0)
fig = plt.gcf()
fig.set_size_inches(24,12)
plot_scalogram.show()

# %%
ls
# Out:
# 2500yrData2.csv         SST.csv                 WavePal Sr-Fe Ti.ipynb
# Cariaco.csv             SolarActivity.csv
# El Junco .csv           Sr-FEWAVELET.ipynb

# %%
data=pd.read_csv("Cariaco.csv")

# %%
x1 = data['tismooth%'].values
t = data['Yr CE'].values

# %%
x = wv.Wavepal(t,x1,"Age","Ti%",t_units="yr",mydata_units="%")

# %%
help(x.__init__)
# Out:
# Help on method __init__ in module wavepal.Wavepal:
#
# __init__(self, t, mydata, t_axis_label='', mydata_axis_label='', t_units=None, mydata_units=None) method of wavepal.Wavepal.Wavepal instance
#     Constructor of Wavepal class. It Initializes all the variables of Wavepal class with an access outside Wavepal (the user can access them). The list of available variables is given in this function.
#     Required Inputs:
#     - t [1-dim numpy array of floats]: the times of the time series, distinct and in ascending order.
#     - mydata [1-dim numpy array of floats - size=time.size]: the data at the times given by 't'.
#     Optional Inputs:
#     - t_axis_label="": label for the time axis in figures
#     - mydata_axis_label="": label for the data axis in figures
#     - t_units=None: units of 't' (string type)
#     - mydata_units=None: units of 'mydata' (string type).
#     Outputs:
#     /
#     -----------------------------
#     This is part of WAVEPAL
#     (C) 2016 G. Lenoir

# %%
x.check_data()

# %%
plot_timestep=x.plot_timestep()
plot_timestep.show()

# %%
plot_trend=x.plot_trend(pol_degree=-1)    # no trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=0)    # constant trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=5)    
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=7)   
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=9)    
plot_trend.show()

# %%
x.choose_trend_degree(7)

# %%
x.trend_vectors()

# %%
x.carma_params(make_carma_fig=True,nbins=20,dpi=400,path_to_figure_folder="/Users/kurtwogau/Documents/")
# Out:
# ****************************
# *        CARMA PACK        *
# ****************************
#
# FIRST ROUND (to estimate the number of independent samples): with  10000  samples
# **********************************************************************************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Decorrelation length (in number of samples) - Estimation:  23
#
# SECOND ROUND: generates  23000  samples
# ***************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Decorrelation length (in number of samples):  15
# **************************************
# *        BUILD CARMA MATRIX K        *
# **************************************
# Computing the median parameters of the CAR-1 process from  1534  MCMC samples.
# Median parameters:
# --------------------
# alpha:  0.04415396892556672
# std white noise:  0.0064548764262216335

# %%
percentilepercenti =np.zeros(2)
percentile[0]=95.
percentile[1]=99.9

# %%
x.freq_analysis(freqstep=0.0001,D=600.,percentile=percentile,n_moments=12,computes_amplitude=True)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 301.12it/s]
#   2%|▏         | 16/805 [00:00<00:05, 151.90it/s]
# Re-estimated D factor (WOSA):  629.1766666666667
# Preliminary steps for the WOSA periodogram:
# Re-estimated frequency range: from  0.001630269686698851  to  0.08206511817097024
# Main loop, over the frequencies:
# 100%|██████████| 805/805 [00:04<00:00, 164.30it/s]

# %%
plot_periodogram=x.plot_periodogram(fontsize_legend=10)
plot_periodogram.show()

# %%
theta=np.linspace(t[0],t[-1],2000)

# %%
x.timefreq_analysis(theta=theta,w0=5.5,permin=10.,percentile=percentile)
# Out:
#   0%|          | 8/2000 [00:00<00:28, 71.14it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [00:36<00:00, 54.27it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# Re-estimated period range: from  10.0  to  298.57055729177847
# Main loop, over the time-frequency plane:
#  40%|████      | 40/99 [01:58<02:54,  2.95s/it]

# %%
Time_string=[0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500., 5000., 5500., 6000.]
period_string=[10., 21., 41., 100., 200., 400., 800., 1500.]
dashed_periods=[21., 41., 100.]

# %%
plot_scalogram=x.plot_scalogram(color_cl_anal=['m','g'],fontsize_title=30,fontsize_ticks=20,fontsize_axes=20,time_string=time_string,period_string=period_string,dashed_periods=dashed_periods,linewidth_cl=4,global_scal_xlabel_ticks="bottom",decimals=2,linewidth_gscal=2.0)
fig = plt.gcf() 
fig.set_size_inches(24,12)
plot_scalogram.show()

# %%
ls
# Out:
# 2500yrData2.csv         SST.csv                 WavePal Sr-Fe Ti.ipynb
# Cariaco.csv             SolarActivity.csv
# El Junco .csv           Sr-FEWAVELET.ipynb

# %%
data=pd.read_csv("El Junco .csv")

# %%
x1 = data['% Sand'].values
t = data['Year (AD/BC)'].values

# %%
x = wv.Wavepal(t,x1,"Year (AD/BC)","% Sand",t_units="yr",mydata_units="%")

# %%
help(x.__init__)
# Out:
# Help on method __init__ in module wavepal.Wavepal:
#
# __init__(self, t, mydata, t_axis_label='', mydata_axis_label='', t_units=None, mydata_units=None) method of wavepal.Wavepal.Wavepal instance
#     Constructor of Wavepal class. It Initializes all the variables of Wavepal class with an access outside Wavepal (the user can access them). The list of available variables is given in this function.
#     Required Inputs:
#     - t [1-dim numpy array of floats]: the times of the time series, distinct and in ascending order.
#     - mydata [1-dim numpy array of floats - size=time.size]: the data at the times given by 't'.
#     Optional Inputs:
#     - t_axis_label="": label for the time axis in figures
#     - mydata_axis_label="": label for the data axis in figures
#     - t_units=None: units of 't' (string type)
#     - mydata_units=None: units of 'mydata' (string type).
#     Outputs:
#     /
#     -----------------------------
#     This is part of WAVEPAL
#     (C) 2016 G. Lenoir

# %%
x.check_data()

# %%
plot_timestep=x.plot_timestep()
plot_timestep.show()

# %%
plot_trend=x.plot_trend(pol_degree=-1)    # no trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=0)    # constant trend
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=5)    
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=7)   
plot_trend.show()
plot_trend=x.plot_trend(pol_degree=9)    
plot_trend.show()

# %%
x.choose_trend_degree(7)

# %%
x.trend_vectors()

# %%
x.carma_params(make_carma_fig=True,nbins=20,dpi=400,path_to_figure_folder="/Users/kurtwogau/Documents/")
# Out:
# ****************************
# *        CARMA PACK        *
# ****************************
#
# FIRST ROUND (to estimate the number of independent samples): with  10000  samples
# **********************************************************************************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Decorrelation length (in number of samples) - Estimation:  30
#
# SECOND ROUND: generates  30000  samples
# ***************************************
# Calculating sigma...
# Calculating log-likelihoods...
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Plotting parameter summary
# Decorrelation length (in number of samples):  17
# **************************************
# *        BUILD CARMA MATRIX K        *
# **************************************
# Computing the median parameters of the CAR-1 process from  1765  MCMC samples.
# Median parameters:
# --------------------
# alpha:  0.046409408059325835
# std white noise:  1.050952214797341

# %%
percentile=np.zeros(2)
percentile[0]=95.
percentile[1]=99.9

# %%
x.freq_analysis(freqstep=0.0001,D=600.,percentile=percentile,n_moments=12,computes_amplitude=True)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 647.92it/s]
#   8%|▊         | 16/207 [00:00<00:01, 155.55it/s]
# Re-estimated D factor (WOSA):  613.2307692307693
# Preliminary steps for the WOSA periodogram:
# Re-estimated frequency range: from  0.001803041025884358  to  0.022423401422079894
# Main loop, over the frequencies:
# 100%|██████████| 207/207 [00:01<00:00, 166.26it/s]

# %%
plot_periodogram=x.plot_periodogram(fontsize_legend=10)
plot_periodogram.show()

# %%
theta=np.linspace(t[0],t[-1],2000)

# %%
x.timefreq_analysis(theta=theta,w0=5.5,permin=10.,percentile=percentile)
# Out:
#   1%|          | 15/2000 [00:00<00:13, 144.01it/s]
# Weights for the scalogram and Shannon-Nyquist exclusion zone:
# 100%|██████████| 2000/2000 [00:17<00:00, 112.62it/s]
#   2%|▏         | 2/94 [00:00<00:07, 12.04it/s]
# Re-estimated period range: from  12.745619018798894  to  320.00032
# Main loop, over the time-frequency plane:
# 100%|██████████| 94/94 [04:26<00:00,  2.83s/it]

# %%
time_string=[0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500., 5000., 5500., 6000.]
period_string=[10., 21., 41., 100., 200., 400., 800., 1500.]
dashed_periods=[21., 41., 100.]

# %%
plot_scalogramplot_sca =x.plot_scalogram(color_cl_anal=['m','g'],fontsize_title=30,fontsize_ticks=20,fontsize_axes=20,time_string=time_string,period_string=period_string,dashed_periods=dashed_periods,linewidth_cl=4,global_scal_xlabel_ticks="bottom",decimals=2,linewidth_gscal=2.0)
fig = plt.gcf() 
fig.set_size_inches(24,12)
plot_scalogram.show()
